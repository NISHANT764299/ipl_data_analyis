# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("matches.csv")

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df.tail()
# Out:
#            id season       city        date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  2024-05-26        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
df.shape
# Out:
# (1095, 20)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
df.describe()
# Out:
#                  id  result_margin  target_runs  target_overs
# count  1.095000e+03    1076.000000  1092.000000   1092.000000
# mean   9.048283e+05      17.259294   165.684066     19.759341
# std    3.677402e+05      21.787444    33.427048      1.581108
# min    3.359820e+05       1.000000    43.000000      5.000000
# 25%    5.483315e+05       6.000000   146.000000     20.000000
# 50%    9.809610e+05       8.000000   166.000000     20.000000
# 75%    1.254062e+06      20.000000   187.000000     20.000000
# max    1.426312e+06     146.000000   288.000000     20.000000

# %%
df['winner'].shape
# Out:
# (1095,)

# %%
df[['winner','team1','team2']]
# Out:
#                            winner                        team1  \
# 0           Kolkata Knight Riders  Royal Challengers Bangalore
# 1             Chennai Super Kings              Kings XI Punjab
# 2                Delhi Daredevils             Delhi Daredevils
# 3     Royal Challengers Bangalore               Mumbai Indians
# 4           Kolkata Knight Riders        Kolkata Knight Riders
# ...                           ...                          ...
# 1090          Sunrisers Hyderabad                 Punjab Kings
# 1091        Kolkata Knight Riders          Sunrisers Hyderabad
# 1092             Rajasthan Royals  Royal Challengers Bengaluru
# 1093          Sunrisers Hyderabad          Sunrisers Hyderabad
# 1094        Kolkata Knight Riders          Sunrisers Hyderabad
#
#                             team2
# 0           Kolkata Knight Riders
# 1             Chennai Super Kings
# 2                Rajasthan Royals
# 3     Royal Challengers Bangalore
# ...

# %%
df.iloc[1]
# Out:
# id                                                     335983
# season                                                2007/08
# city                                               Chandigarh
# date                                               2008-04-19
# match_type                                             League
# player_of_match                                    MEK Hussey
# venue              Punjab Cricket Association Stadium, Mohali
# team1                                         Kings XI Punjab
# team2                                     Chennai Super Kings
# toss_winner                               Chennai Super Kings
# toss_decision                                             bat
# winner                                    Chennai Super Kings
# result                                                   runs
# result_margin                                            33.0
# target_runs                                             241.0
# ...

# %%
df.iloc[1:11:2]
# Out:
#        id   season        city        date match_type player_of_match  \
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                team1  \
# 1  Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
# 3                            Wankhede Stadium       Mumbai Indians
# 5                      Sawai Mansingh Stadium     Rajasthan Royals
# 7             MA Chidambaram Stadium, Chepauk  Chennai Super Kings
# 9  Punjab Cricket Association Stadium, Mohali      Kings XI Punjab
#
#                          team2          toss_winner toss_decision  \
# 1          Chennai Super Kings  Chennai Super Kings           bat
# ...

# %%
df.iloc[[1,4,7]]
# Out:
#        id   season        city        date match_type player_of_match  \
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
#
#                                         venue                  team1  \
# 1  Punjab Cricket Association Stadium, Mohali        Kings XI Punjab
# 4                                Eden Gardens  Kolkata Knight Riders
# 7             MA Chidambaram Stadium, Chepauk    Chennai Super Kings
#
#                  team2          toss_winner toss_decision  \
# 1  Chennai Super Kings  Chennai Super Kings           bat
# 4      Deccan Chargers      Deccan Chargers           bat
# 7       Mumbai Indians       Mumbai Indians         field
#
#                   winner   result  result_margin  target_runs  target_overs  \
# 1    Chennai Super Kings     runs           33.0        241.0          20.0
# ...

# %%
df.iloc[:,[4,5,10]]
# Out:
#        match_type  player_of_match toss_decision
# 0          League      BB McCullum         field
# 1          League       MEK Hussey           bat
# 2          League      MF Maharoof           bat
# 3          League       MV Boucher           bat
# 4          League        DJ Hussey           bat
# ...           ...              ...           ...
# 1090       League  Abhishek Sharma           bat
# 1091  Qualifier 1         MA Starc           bat
# 1092   Eliminator         R Ashwin         field
# 1093  Qualifier 2    Shahbaz Ahmed         field
# 1094        Final         MA Starc           bat
#
# [1095 rows x 3 columns]

# %%
mask = df['venue'] == "Eden Gardens"
df[mask]
# Out:
#           id   season     city        date match_type player_of_match  \
# 4     335986  2007/08  Kolkata  2008-04-20     League       DJ Hussey
# 15    335997  2007/08  Kolkata  2008-04-29     League   ST Jayasuriya
# 28    336010  2007/08  Kolkata  2008-05-08     League      SC Ganguly
# 34    336017  2007/08  Kolkata  2008-05-13     League   Shoaib Akhtar
# 41    336025  2007/08  Kolkata  2008-05-18     League         M Ntini
# ..       ...      ...      ...         ...        ...             ...
# 721  1178401     2019  Kolkata  2019-04-12     League        S Dhawan
# 724  1178404     2019  Kolkata  2019-04-14     League     Imran Tahir
# 730  1178410     2019  Kolkata  2019-04-19     League         V Kohli
# 738  1178418     2019  Kolkata  2019-04-25     League        VR Aaron
# 742  1178422     2019  Kolkata  2019-04-28     League      AD Russell
#
#             venue                        team1                        team2  \
# ...

# %%
df[mask].shape
# Out:
# (77, 20)

# %%
df[mask].shape[0]
# Out:
# 77

# %%
df1 = df['winner']=="Royal Challengers Bangalore"
df[df1]
# Out:
#            id   season        city        date match_type player_of_match  \
# 3      335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 21     336034  2007/08   Bangalore  2008-05-03     League         P Kumar
# 45     336029  2007/08     Chennai  2008-05-21     League        A Kumble
# 49     336002  2007/08   Hyderabad  2008-05-25     League   R Vinay Kumar
# 59     392182     2009   Cape Town  2009-04-18     League        R Dravid
# ...       ...      ...         ...         ...        ...             ...
# 976   1359501     2023  Chandigarh  2023-04-20     League  Mohammed Siraj
# 981   1359506     2023   Bengaluru  2023-04-23     League      GJ Maxwell
# 992   1359517     2023     Lucknow  2023-05-01     League    F du Plessis
# 1009  1359534     2023      Jaipur  2023-05-14     League      WD Parnell
# 1014  1359539     2023   Hyderabad  2023-05-18     League         V Kohli
#
#                                                   venue  \
# ...

# %%
df['winner'].value_counts()
# Out:
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df['winner'].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
df['toss_decision'].value_counts().plot(kind = 'pie')
# Out:
# <Axes: ylabel='toss_decision'>

# %%
df['result_margin'].plot(kind ='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
myser = df['winner'].value_counts()
myser
# Out:
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Lucknow Super Giants            24
# Punjab Kings                    24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df['team1'].value_counts()
# Out:
# Royal Challengers Bangalore    135
# Chennai Super Kings            128
# Mumbai Indians                 123
# Kolkata Knight Riders          121
# Rajasthan Royals               101
# Kings XI Punjab                 92
# Sunrisers Hyderabad             86
# Delhi Daredevils                85
# Delhi Capitals                  41
# Deccan Chargers                 39
# Punjab Kings                    31
# Lucknow Super Giants            23
# Pune Warriors                   23
# Gujarat Titans                  21
# Gujarat Lions                   16
# Royal Challengers Bengaluru      9
# Rising Pune Supergiant           7
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Name: team1, dtype: int64

# %%
df['team2'].value_counts()
# Out:
# Mumbai Indians                 138
# Kolkata Knight Riders          130
# Rajasthan Royals               120
# Chennai Super Kings            110
# Royal Challengers Bangalore    105
# Kings XI Punjab                 98
# Sunrisers Hyderabad             96
# Delhi Daredevils                76
# Delhi Capitals                  50
# Deccan Chargers                 36
# Punjab Kings                    25
# Gujarat Titans                  24
# Pune Warriors                   23
# Lucknow Super Giants            21
# Gujarat Lions                   14
# Rising Pune Supergiant           9
# Rising Pune Supergiants          7
# Kochi Tuskers Kerala             7
# Royal Challengers Bengaluru      6
# Name: team2, dtype: int64

# %%
(df['team1'].value_counts() + df['team2'].value_counts()).sort_values()
# Out:
# Rising Pune Supergiants         14
# Kochi Tuskers Kerala            14
# Royal Challengers Bengaluru     15
# Rising Pune Supergiant          16
# Gujarat Lions                   30
# Lucknow Super Giants            44
# Gujarat Titans                  45
# Pune Warriors                   46
# Punjab Kings                    56
# Deccan Chargers                 75
# Delhi Capitals                  91
# Delhi Daredevils               161
# Sunrisers Hyderabad            182
# Kings XI Punjab                190
# Rajasthan Royals               221
# Chennai Super Kings            238
# Royal Challengers Bangalore    240
# Kolkata Knight Riders          251
# Mumbai Indians                 261
# dtype: int64

# %%
df
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.sort_values('city')
# Out:
#           id   season       city        date   match_type player_of_match  \
# 787  1216526  2020/21  Abu Dhabi  2020-10-16       League       Q de Kock
# 779  1216523  2020/21  Abu Dhabi  2020-10-10       League      KD Karthik
# 782  1216529  2020/21  Abu Dhabi  2020-10-11       League       Q de Kock
# 808  1216506  2020/21  Abu Dhabi  2020-11-01       League      RD Gaikwad
# 398   729279     2014  Abu Dhabi  2014-04-16       League       JH Kallis
# ..       ...      ...        ...         ...          ...             ...
# 807  1216535  2020/21        NaN  2020-10-31       League    Ishan Kishan
# 809  1216530  2020/21        NaN  2020-11-01       League      PJ Cummins
# 811  1216495  2020/21        NaN  2020-11-03       League        S Nadeem
# 812  1237177  2020/21        NaN  2020-11-05  Qualifier 1       JJ Bumrah
# 815  1237181  2020/21        NaN  2020-11-10        Final        TA Boult
#
#                                    venue                  team1  \
# ...

# %%
df.sort_values(['city','date'])
# Out:
#           id   season       city        date   match_type player_of_match  \
# 398   729279     2014  Abu Dhabi  2014-04-16       League       JH Kallis
# 400   729283     2014  Abu Dhabi  2014-04-18       League      GJ Maxwell
# 401   729285     2014  Abu Dhabi  2014-04-18       League       AM Rahane
# 405   729293     2014  Abu Dhabi  2014-04-21       League        SK Raina
# 411   729305     2014  Abu Dhabi  2014-04-26       League        PV Tambe
# ..       ...      ...        ...         ...          ...             ...
# 807  1216535  2020/21        NaN  2020-10-31       League    Ishan Kishan
# 809  1216530  2020/21        NaN  2020-11-01       League      PJ Cummins
# 811  1216495  2020/21        NaN  2020-11-03       League        S Nadeem
# 812  1237177  2020/21        NaN  2020-11-05  Qualifier 1       JJ Bumrah
# 815  1237181  2020/21        NaN  2020-11-10        Final        TA Boult
#
#                                    venue                  team1  \
# ...

# %%
df.drop_duplicates(subset=['city'])
# Out:
#            id   season            city        date match_type  \
# 0      335982  2007/08       Bangalore  2008-04-18     League
# 1      335983  2007/08      Chandigarh  2008-04-19     League
# 2      335984  2007/08           Delhi  2008-04-19     League
# 3      335985  2007/08          Mumbai  2008-04-20     League
# 4      335986  2007/08         Kolkata  2008-04-20     League
# 5      335987  2007/08          Jaipur  2008-04-21     League
# 6      335988  2007/08       Hyderabad  2008-04-22     League
# 7      335989  2007/08         Chennai  2008-04-23     League
# 58     392181     2009       Cape Town  2009-04-18     League
# 62     392185     2009  Port Elizabeth  2009-04-20     League
# 63     392186     2009          Durban  2009-04-21     League
# 73     392198     2009       Centurion  2009-04-28     League
# 78     392203     2009     East London  2009-05-01     League
# 81     392206     2009    Johannesburg  2009-05-02     League
# ...

# %%
df.drop_duplicates('season',keep='last')
# Out:
#            id   season          city        date match_type player_of_match  \
# 57     336040  2007/08        Mumbai  2008-06-01      Final       YK Pathan
# 114    392239     2009  Johannesburg  2009-05-24      Final        A Kumble
# 174    419165  2009/10        Mumbai  2010-04-25      Final        SK Raina
# 247    501271     2011       Chennai  2011-05-28      Final         M Vijay
# 321    548381     2012       Chennai  2012-05-27      Final        MS Bisla
# 397    598073     2013       Kolkata  2013-05-26      Final      KA Pollard
# 457    734049     2014     Bangalore  2014-06-01      Final       MK Pandey
# 516    829823     2015       Kolkata  2015-05-24      Final       RG Sharma
# 576    981019     2016     Bangalore  2016-05-29      Final     BCJ Cutting
# 635   1082650     2017     Hyderabad  2017-05-21      Final       KH Pandya
# 695   1136620     2018        Mumbai  2018-05-27      Final       SR Watson
# ...

# %%
dv = pd.read_csv("deliveries.csv")

# %%
dv.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
dv.shape
# Out:
# (260920, 17)

# %%
runs = dv.groupby('batter')
runs

# %%
runs['batsman_runs'].sum().sort_values(ascending=False).head()
# Out:
# batter
# V Kohli      8014
# S Dhawan     6769
# RG Sharma    6630
# DA Warner    6567
# SK Raina     5536
# Name: batsman_runs, dtype: int64

# %%
mask = dv['batsman_runs']==4
dv1=dv[mask]

# %%
dv1.shape[0]
# Out:
# 29850

# %%
dv1.groupby('batter')['batsman_runs'].count().sort_values(ascending=False)
# Out:
# batter
# S Dhawan        768
# V Kohli         708
# DA Warner       663
# RG Sharma       599
# SK Raina        506
#                ...
# B Stanlake        1
# J Theron          1
# SH Johnson        1
# SD Lad            1
# DE Bollinger      1
# Name: batsman_runs, Length: 538, dtype: int64

# %%
dv.groupby('batter')['batsman_runs'].count().sort_values(ascending= False).head()
# Out:
# batter
# V Kohli      6236
# S Dhawan     5483
# RG Sharma    5183
# DA Warner    4849
# SK Raina     4177
# Name: batsman_runs, dtype: int64

# %%
d_o = dv[dv['over']>15]

# %%
all_batter = d_o.groupby('batter')['batsman_runs'].count()
x= all_batter >200
b_list = all_batter[x].index.tolist()
b_list
# Out:
# ['A Badoni',
#  'A Mishra',
#  'AB de Villiers',
#  'AD Mathews',
#  'AD Russell',
#  'AM Rahane',
#  'AR Patel',
#  'AT Rayudu',
#  'B Kumar',
#  'BJ Hodge',
#  'CH Gayle',
#  'CH Morris',
#  'DA Miller',
#  'DA Warner',
#  'DJ Bravo',
#  'DJ Hooda',
#  'EJG Morgan',
#  'F du Plessis',
#  'GJ Maxwell',
#  'HH Pandya',
#  'Harbhajan Singh',
#  'IK Pathan',
#  'JA Morkel',
#  'JC Buttler',
#  'JP Duminy',
#  'JP Faulkner',
#  'KA Pollard',
#  'KD Karthik',
#  'KH Pandya',
#  'KL Rahul',
#  'KM Jadhav',
#  'KS Williamson',
#  'MK Pandey',
#  'MK Tiwary',
#  'MP Stoinis',
#  'MS Dhoni',
#  'Mandeep Singh',
#  'N Pooran',
#  'NV Ojha',
#  'P Kumar',
#  'PJ Cummins',
#  'PP Chawla',
#  'R Ashwin',
#  'R Parag',
#  'R Tewatia',
#  'R Vinay Kumar',
#  'RA Jadeja',
#  'RG Sharma',
#  'RK Singh',
#  'RR Pant',
#  'RV Uthappa',
#  'Rashid Khan',
#  'S Badrinath',
#  'S Dhawan',
#  'S Dube',
#  'SA Yadav',
#  'SK Raina',
#  'SO Hetmyer',
#  'SPD Smith',
#  'SS Iyer',
#  'SS Tiwary',
# ...

# %%
 dv2 = dv[dv['batter'].isin(b_list)]

# %%
runs = dv2.groupby('batter')['batsman_runs'].sum()

# %%
balls =  dv2.groupby('batter')['batsman_runs'].count()

# %%
sr = (runs/balls)*100

# %%
sr.sort_values(ascending =False)
# Out:
# batter
# AD Russell       164.224422
# TH David         158.033573
# N Pooran         154.768154
# Rashid Khan      153.521127
# GJ Maxwell       150.488599
#                     ...
# PP Chawla        107.586207
# R Vinay Kumar    107.266436
# P Kumar          105.263158
# B Kumar           90.532544
# A Mishra          86.590909
# Name: batsman_runs, Length: 71, dtype: float64

# %%
new = dv.merge(df,left_on = 'match_id',right_on = 'id')

# %%
new
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
d =  new.groupby(['season','batter'])['batsman_runs'].sum().sort_values(ascending = False).reset_index().drop_duplicates(subset = 'season',keep ='first')

# %%
d.sort_values('season')[['season','batter']]
# Out:
#      season         batter
# 26  2007/08       SE Marsh
# 38     2009      ML Hayden
# 25  2009/10   SR Tendulkar
# 28     2011       CH Gayle
# 6      2012       CH Gayle
# 7      2013     MEK Hussey
# 15     2014     RV Uthappa
# 42     2015      DA Warner
# 0      2016        V Kohli
# 17     2017      DA Warner
# 5      2018  KS Williamson
# 10     2019      DA Warner
# 13  2020/21       KL Rahul
# 20     2021     RD Gaikwad
# 2      2022     JC Buttler
# 1      2023   Shubman Gill
# 4      2024        V Kohli

# %%
dv
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
mask = dv['batsman_runs']==6
dv1=dv[mask]
dv1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 10        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 20        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 25        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 60        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 65        335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260868   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260869   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260889   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260895   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260908   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
pt = dv1.pivot_table(index = 'over',columns = 'batting_team',values = 'batsman_runs',aggfunc = 'count')

# %%
pt
# Out:
# batting_team  Chennai Super Kings  Deccan Chargers  Delhi Capitals  \
# over
# 0                             9.0              3.0             7.0
# 1                            36.0             21.0            17.0
# 2                            67.0             11.0            31.0
# 3                            71.0             17.0            32.0
# 4                            75.0             27.0            41.0
# 5                            85.0             22.0            22.0
# 6                            48.0             11.0            19.0
# 7                            40.0             13.0            22.0
# 8                            64.0             17.0            21.0
# 9                            48.0             14.0            20.0
# 10                           76.0             15.0            21.0
# 11                           76.0             26.0            20.0
# 12                           75.0             23.0            37.0
# ...

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='batting_team', ylabel='over'>

# %%
df.corr()
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_9160\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                      id  result_margin  target_runs  target_overs
# id             1.000000      -0.006853     0.238859      0.046388
# result_margin -0.006853       1.000000     0.395120      0.030970
# target_runs    0.238859       0.395120     1.000000      0.352361
# target_overs   0.046388       0.030970     0.352361      1.000000

# %%
sns.heatmap(df.corr())
# Out:
# C:\Users\nisha\AppData\Local\Temp\ipykernel_9160\58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %%
df.head(5)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
df.set_index('id')
# Out:
#           season        city        date   match_type  player_of_match  \
# id
# 335982   2007/08   Bangalore  2008-04-18       League      BB McCullum
# 335983   2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 335984   2007/08       Delhi  2008-04-19       League      MF Maharoof
# 335985   2007/08      Mumbai  2008-04-20       League       MV Boucher
# 335986   2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...          ...         ...         ...          ...              ...
# 1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                      venue  \
# id
# ...

# %%
df.reset_index()
# Out:
#       index       id   season        city        date   match_type  \
# 0         0   335982  2007/08   Bangalore  2008-04-18       League
# 1         1   335983  2007/08  Chandigarh  2008-04-19       League
# 2         2   335984  2007/08       Delhi  2008-04-19       League
# 3         3   335985  2007/08      Mumbai  2008-04-20       League
# 4         4   335986  2007/08     Kolkata  2008-04-20       League
# ...     ...      ...      ...         ...         ...          ...
# 1090   1090  1426307     2024   Hyderabad  2024-05-19       League
# 1091   1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1
# 1092   1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator
# 1093   1093  1426311     2024     Chennai  2024-05-24  Qualifier 2
# 1094   1094  1426312     2024     Chennai  2024-05-26        Final
#
#       player_of_match                                              venue  \
# 0         BB McCullum                              M Chinnaswamy Stadium
# ...

# %%
df.set_index('id')
# Out:
#           season        city        date   match_type  player_of_match  \
# id
# 335982   2007/08   Bangalore  2008-04-18       League      BB McCullum
# 335983   2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 335984   2007/08       Delhi  2008-04-19       League      MF Maharoof
# 335985   2007/08      Mumbai  2008-04-20       League       MV Boucher
# 335986   2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...          ...         ...         ...          ...              ...
# 1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
#                                                      venue  \
# id
# ...

# %%
df.shape
# Out:
# (1095, 20)

# %%
df.dropna()
# Out:
#            id   season           city        date  match_type  \
# 38     336022  2007/08          Delhi  2008-05-17      League
# 41     336025  2007/08        Kolkata  2008-05-18      League
# 60     392183     2009      Cape Town  2009-04-19      League
# 63     392186     2009         Durban  2009-04-21      League
# 89     392214     2009      Centurion  2009-05-07      League
# 192    501215     2011          Kochi  2011-04-18      League
# 221    501245     2011        Kolkata  2011-05-07      League
# 231    501255     2011      Bangalore  2011-05-14      League
# 429    733993     2014          Delhi  2014-05-10      League
# 476    829743     2015  Visakhapatnam  2015-04-22      League
# 508    829807     2015      Hyderabad  2015-05-15      League
# 538    980943     2016      Hyderabad  2016-04-26      League
# 561    980989     2016        Kolkata  2016-05-14      League
# 565    980997     2016  Visakhapatnam  2016-05-17      League
# ...

# %%
df.dropna(axis = 1)
# Out:
#            id   season        date   match_type  \
# 0      335982  2007/08  2008-04-18       League
# 1      335983  2007/08  2008-04-19       League
# 2      335984  2007/08  2008-04-19       League
# 3      335985  2007/08  2008-04-20       League
# 4      335986  2007/08  2008-04-20       League
# ...       ...      ...         ...          ...
# 1090  1426307     2024  2024-05-19       League
# 1091  1426309     2024  2024-05-21  Qualifier 1
# 1092  1426310     2024  2024-05-22   Eliminator
# 1093  1426311     2024  2024-05-24  Qualifier 2
# 1094  1426312     2024  2024-05-26        Final
#
#                                                   venue  \
# 0                                 M Chinnaswamy Stadium
# 1            Punjab Cricket Association Stadium, Mohali
# 2                                      Feroz Shah Kotla
# 3                                      Wankhede Stadium
# 4                                          Eden Gardens
# ...

# %%
df.dropna(how = 'all')
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df.dropna(subset = ['result_margin']).shape
# Out:
# (1076, 20)

# %%
df.fillna(0)
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df['method'].fillna(0)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1090    0
# 1091    0
# 1092    0
# 1093    0
# 1094    0
# Name: method, Length: 1095, dtype: object

# %%
df['result_margin'].fillna(0).sort_values()
# Out:
# 342      0.0
# 511      0.0
# 241      0.0
# 765      0.0
# 475      0.0
#        ...
# 352    130.0
# 496    138.0
# 0      140.0
# 560    144.0
# 620    146.0
# Name: result_margin, Length: 1095, dtype: float64

# %%
df['result_margin'].fillna(method = 'ffill').iloc[342]
# Out:
# 4.0

# %%
df.iloc[342]
# Out:
# id                                      598017
# season                                    2013
# city                                 Bangalore
# date                                2013-04-16
# match_type                              League
# player_of_match                        V Kohli
# venue                    M Chinnaswamy Stadium
# team1              Royal Challengers Bangalore
# team2                         Delhi Daredevils
# toss_winner        Royal Challengers Bangalore
# toss_decision                            field
# winner             Royal Challengers Bangalore
# result                                     tie
# result_margin                              NaN
# target_runs                              153.0
# target_overs                              20.0
# super_over                                   Y
# method                                     NaN
# umpire1                              M Erasmus
# umpire2                            VA Kulkarni
# ...

# %%
df.iloc[343]
# Out:
# id                                                  598018
# season                                                2013
# city                                                  Pune
# date                                            2013-04-17
# match_type                                          League
# player_of_match                                   A Mishra
# venue              Maharashtra Cricket Association Stadium
# team1                                        Pune Warriors
# team2                                  Sunrisers Hyderabad
# toss_winner                                  Pune Warriors
# toss_decision                                        field
# winner                                 Sunrisers Hyderabad
# result                                                runs
# result_margin                                         11.0
# target_runs                                          120.0
# target_overs                                          20.0
# ...

# %%
df = pd.read_csv("sharma-kohli.csv")
df
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
df.plot(kind = 'scatter',x = 'RG Sharma',y = 'V Kohli',color = 'red',title="rohit vs kohli ")
# Out:
# <Axes: title={'center': 'rohit vs kohli '}, xlabel='RG Sharma', ylabel='V Kohli'>

# %%
df['V Kohli'].plot(kind='line')
# Out:
# <Axes: >
